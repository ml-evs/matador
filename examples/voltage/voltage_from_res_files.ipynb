# %% [markdown]
# # Plotting a voltage curve from a folder of res files

# %%
from glob import glob
from matador.hull import QueryConvexHull
from matador.scrapers.castep_scrapers import res2dict
# %matplotlib inline
cursor = [res2dict(file)[0] for file in files]
hull = QueryConvexHull(cursor=cursor, elements=['Li', 'P'])
# Out:
# Constructing binary hull...
# 6 structures within 0.0 eV of the hull with chosen chemical potentials.
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                    ID                    !?!  Pressure  Volume/fu  Hull dist.   Space group  Formula    # fu   Prov.
#                                                (GPa)     (Ang^3)   (meV/atom)
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# * P-CollCode150873                                0.01       21.2          0.0    Cmca         P        4      ICSD
# * LiP-ColCode23621                               -0.02      173.2          0.0   I41/acd      LiP7      8      ICSD
# * LiP-CollCode60774                               0.02      198.4          0.0   P212121     Li3P7      4      ICSD
# * LiP-CollCode182159                             -0.02       31.3          0.0    P21/c       LiP       8      ICSD
# * LiP-CollCode165990                             -0.02       58.4          0.0   P63/mmc      Li3P      4      ICSD
# * Li-bcc                                          0.01       20.3          0.0    Pm-3m        Li       16    AIRSS
# Generating voltage curve...
# Voltage data:
#
# # LiP
# #  Q (mAh/g),	Voltage (V)
#       0.00,	    1.5155
#     123.62,	    1.5155
#     370.87,	    1.1913
#     865.37,	    0.9536
#    2596.10,	    0.8959
#        nan,	    0.0000
