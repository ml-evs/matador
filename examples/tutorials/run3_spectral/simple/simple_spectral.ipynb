# %%
# !run3 -v 2 LiCoO2
# Out:
# 2018-11-07 17:01:25,205 -     INFO: Initialising FullRelaxer object for LiCoO2-CollCode29225
# 2018-11-07 17:01:25,205 -     INFO: Calling CASTEP on LiCoO2-CollCode29225
# 2018-11-07 17:01:25,206 -     INFO: Testing executable castep.
# 2018-11-07 17:01:25,212 -     INFO: Using default MPI library.
# 2018-11-07 17:01:25,213 -     INFO: Detected default MPI.
# 2018-11-07 17:01:25,255 -  WARNING: MPI library tried to use too many cores and failed, rescaling core count and re-running with 4 cores...
# 2018-11-07 17:01:25,255 -  WARNING: stdout:
# 2018-11-07 17:01:25,255 -  WARNING: sterr: --------------------------------------------------------------------------
# There are not enough slots available in the system to satisfy the 8 slots
# that were requested by the application:
#   castep
#
# Either request fewer slots for your application, or make more slots available
# for use.
# --------------------------------------------------------------------------
#
# ...

# %%
# %matplotlib inline
from matador.plotting import plot_spectral

# %% [markdown]
# ## Default plot style

# %%
plot_spectral('completed/LiCoO2-CollCode29225')
# Out:
# Loading settings from /home/matthew/.matadorrc
# Displaying plot...

# %% [markdown]
# ## Exploring the plotting options

# %%
plot_spectral('completed/LiCoO2-CollCode29225',
              plot_dos=True,
              plot_bs=True,
              gap=True,
              highlight_bands=[20],
              preserve_kspace_distance=True,
              title='LiCoO2'
             )
# Out:
# Loading settings from /home/matthew/.matadorrc
# Read bs for completed/LiCoO2-CollCode29225.
# Band gap is indirect with size 0.97662 eV between [0.65615292 0.34384708 0.5       ] and [0.62011763 0.37988237 0.5       ] corresponding to a wavenumber of 0.15908 eV/A
# The smallest direct gap has size 0.99896 eV and lies at [0.64414116 0.35585884 0.5       ]
# Displaying plot...
